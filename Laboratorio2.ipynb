# %% [markdown]
# <a href="https://colab.research.google.com/github/danidb29/ProgramacionParalela/blob/main/Laboratorio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import threading
import random
import time


def ordenar_subvector(subvector,hilo):
  tiempo_inicio = time.time()
  subvector.sort()
  tiempo_fin = time.time()
  tiempo_ejecucion = tiempo_fin - tiempo_inicio
  print(f'Hilo {hilo} : Subvector ordenado(Tiempo: {tiempo_ejecucion} segundos)')
def dividir_vector(vector,num_hilos):
  longitud_subvector = len(vector) // num_hilos
  subvectores = [vector[i:i+longitud_subvector] for i in range(0,len(vector), longitud_subvector)]
  return subvectores
def unir_vectores(subvectores):
  vector_ordenado = [num for subvector in subvectores for num in subvector]
  return vector_ordenado
def ordenar_vector(vector, num_hilos):
  subvectores = dividir_vector(vector, num_hilos)
  threads = []
  for i, subvector in enumerate(subvectores):
    thread = threading.Thread(target=ordenar_subvector, args=(subvector, i))
    thread.start()
    threads.append(thread)
  for thread in threads:
    thread.join()
  vector_ordenado = unir_vectores(subvectores)
  print(f'Vector ordenado final: {vector_ordenado}')

vector_grande = [random.randint(1,10000) for _ in range(10000)]
num_hilos = int(input('Ingrese la cantidad de hilos: '))
ordenar_vector(vector_grande, num_hilos)

#Al asignar mas hilos el tiempo en cada hilo se ve reducido ya que el procesamiento de cantidad de datos
#por hilo es menor, esto funciona gracias al tamano de los datos que estamos procesando, este ejercicio tiene sentido
#por que la division de subvectores y el asignamiento de un hilo a cada uno es de una cantidad significativa de datos.
# Out:
# Ingrese la cantidad de hilos: 11
# Hilo 0 : Subvector ordenado(Tiempo: 0.00014519691467285156 segundos)Hilo 1 : Subvector ordenado(Tiempo: 0.00012421607971191406 segundos)
#
# Hilo 2 : Subvector ordenado(Tiempo: 0.00013136863708496094 segundos)
# Hilo 3 : Subvector ordenado(Tiempo: 0.00016570091247558594 segundos)Hilo 4 : Subvector ordenado(Tiempo: 0.0001270771026611328 segundos)
#
# Hilo 5 : Subvector ordenado(Tiempo: 0.00013780593872070312 segundos)
# Hilo 6 : Subvector ordenado(Tiempo: 0.00020241737365722656 segundos)Hilo 7 : Subvector ordenado(Tiempo: 0.00015878677368164062 segundos)
#
# Hilo 8 : Subvector ordenado(Tiempo: 0.00015354156494140625 segundos)
# Hilo 9 : Subvector ordenado(Tiempo: 0.00013756752014160156 segundos)
# Hilo 10 : Subvector ordenado(Tiempo: 0.00012969970703125 segundos)
# Hilo 11 : Subvector ordenado(Tiempo: 7.152557373046875e-07 segundos)
